# %%
import auth
import api
import pprint
auth.login()

# %%
btc_data = api.getHistoricals('BTC')['data_points']
eth_data = api.getHistoricals('ETH')['data_points']
ltc_data = api.getHistoricals('LTC')['data_points']

btc_data = [float(point['low_price']) for point in btc_data]
eth_data = [float(point['low_price']) for point in eth_data]
ltc_data = [float(point['low_price']) for point in ltc_data]

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
np.corrcoef(btc_data, eth_data)[0][1]
# Out:
# 0.7043319790053458

# %%
np.corrcoef(btc_data, ltc_data)[0][1]
# Out:
# 0.513215529463457

# %%
np.corrcoef(ltc_data, eth_data)[0][1]
# Out:
# 0.9199850559870753

# %%
fig, ax = plt.subplots()
ax.plot(eth_data)
