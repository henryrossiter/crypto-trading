# %%
import auth
import api
import pprint
auth.login()

# %%
api.getTradeableCryptoList()
# Out:
# [{'asset_currency': {'brand_color': 'EA963D',
#    'code': 'BTC',
#    'id': 'd674efea-e623-4396-9026-39574b92b093',
#    'increment': '0.000000010000000000',
#    'name': 'Bitcoin',
#    'type': 'cryptocurrency'},
#   'display_only': False,
#   'id': '3d961844-d360-45fc-989b-f6fca761d511',
#   'max_order_size': '15.0000000000000000',
#   'min_order_size': '0.000010000000000000',
#   'min_order_price_increment': '0.010000000000000000',
#   'min_order_quantity_increment': '0.000000010000000000',
#   'name': 'Bitcoin to US Dollar',
#   'quote_currency': {'brand_color': '',
#    'code': 'USD',
#    'id': '1072fc76-1862-41ab-82c2-485837590762',
#    'increment': '0.010000000000000000',
#    'name': 'US Dollar',
#    'type': 'fiat'},
#   'symbol': 'BTC-USD',
#   'tradability': 'tradable'},
#  {'asset_currency': {'brand_color': '707DB5',
#    'code': 'ETH',
#    'id': 'c527c04a-394b-4a44-ae07-19b901ca609c',
#    'increment': '0.000000000000000001',
#    'name': 'Ethereum',
# ...

# %%
btc = api.getCryptoQuote('BTC')['ask_price']
eth = api.getCryptoQuote('ETH')['ask_price']
ltc = api.getCryptoQuote('LTC')['ask_price']

# %%
btc
# Out:
# '8560.580000'

# %%
btc
# Out:
# '8448.778492'

# %%
print('cost of 1 ETH: {} BTC'.format(float(eth)/float(btc)))
print('cost of 1 LTC: {} BTC'.format(float(ltc)/float(btc)))
# Out:
# cost of 1 ETH: 0.01916085504588466 BTC
# cost of 1 LTC: 0.006430554316395493 BTC

# %%
api.getTradeableCryptoList()
# Out:
# [{'asset_currency': {'brand_color': 'EA963D',
#    'code': 'BTC',
#    'id': 'd674efea-e623-4396-9026-39574b92b093',
#    'increment': '0.000000010000000000',
#    'name': 'Bitcoin',
#    'type': 'cryptocurrency'},
#   'display_only': False,
#   'id': '3d961844-d360-45fc-989b-f6fca761d511',
#   'max_order_size': '15.0000000000000000',
#   'min_order_size': '0.000010000000000000',
#   'min_order_price_increment': '0.010000000000000000',
#   'min_order_quantity_increment': '0.000000010000000000',
#   'name': 'Bitcoin to US Dollar',
#   'quote_currency': {'brand_color': '',
#    'code': 'USD',
#    'id': '1072fc76-1862-41ab-82c2-485837590762',
#    'increment': '0.010000000000000000',
#    'name': 'US Dollar',
#    'type': 'fiat'},
#   'symbol': 'BTC-USD',
#   'tradability': 'tradable'},
#  {'asset_currency': {'brand_color': '707DB5',
#    'code': 'ETH',
#    'id': 'c527c04a-394b-4a44-ae07-19b901ca609c',
#    'increment': '0.000000000000000001',
#    'name': 'Ethereum',
# ...
